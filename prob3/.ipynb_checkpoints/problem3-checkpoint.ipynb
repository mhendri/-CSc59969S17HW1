# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats as stats
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import matplotlib
# Numpy options
np.random.seed(78)
# Pandas options
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 400)
# Matplotlib options
matplotlib.rcParams['image.cmap'] = 'viridis'
# %matplotlib inline
matplotlib.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10,6)

# %%
df1 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='94-98 FAH')

# %%
print(df1)
# Out:
#     Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                          Total fruit
# 6                                        Apples, Total
# 7                                      Apples as fruit
# 8                                          Apple juice
# 9                                              Bananas
# 10                                             Berries
# 11                                              Grapes
# 12                                              Melons
# 13                                      Oranges, Total
# 14                                    Oranges as fruit
# ...

# %%
df_men=df1[78:91]

# %%
print(df_men)
# Out:
#    Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
# 90                                  Vegetables, Total
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 78      80.18      77.14      83.22      80.98       77.4      84.56
# ...

# %%
df_men=df_men[['Unnamed: 7','Unnamed: 8','Unnamed: 9']]

# %%
print(df_men)
# Out:
#    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 78      89.18      86.79      91.57
# 79      88.78      81.91      95.65
# 80      95.42      93.98      96.86
# 81      84.21      80.33      88.09
# 82      88.79      86.14      91.44
# 83      80.74      75.26      86.22
# 84      85.66      83.12       88.2
# 85      92.31      88.68      95.94
# 86      85.15      82.45      87.85
# 87      79.82      75.07      84.57
# 88      88.95      85.97      91.93
# 89      74.61         68      81.22
# 90      62.44      60.74      64.14

# %%
df_men.columns = ['Mean', 'Lower','Upper']

# %%
df_men = df_men.drop(df_men.index[1])

# %%
print(df_men)
# Out:
#      Mean  Lower  Upper
# 78  89.18  86.79  91.57
# 79  88.78  81.91  95.65
# 80  95.42  93.98  96.86
# 81  84.21  80.33  88.09
# 82  88.79  86.14  91.44
# 83  80.74  75.26  86.22
# 84  85.66  83.12   88.2
# 85  92.31  88.68  95.94
# 86  85.15  82.45  87.85
# 87  79.82  75.07  84.57
# 88  88.95  85.97  91.93
# 89  74.61     68  81.22
# 90  62.44  60.74  64.14

# %%
print(df_men)
# Out:
#      Mean  Lower  Upper
# 78  89.18  86.79  91.57
# 79  88.78  81.91  95.65
# 80  95.42  93.98  96.86
# 81  84.21  80.33  88.09
# 82  88.79  86.14  91.44
# 83  80.74  75.26  86.22
# 84  85.66  83.12   88.2
# 85  92.31  88.68  95.94
# 86  85.15  82.45  87.85
# 87  79.82  75.07  84.57
# 88  88.95  85.97  91.93
# 89  74.61     68  81.22
# 90  62.44  60.74  64.14

# %%
df_men.ix['78','Fruit Type']= 'Apples'

# %%
print(df_men)
# Out:
#      Mean  Lower  Upper Fruit Type
# 78  89.18  86.79  91.57        NaN
# 80  95.42  93.98  96.86        NaN
# 81  84.21  80.33  88.09        NaN
# 82  88.79  86.14  91.44        NaN
# 83  80.74  75.26  86.22        NaN
# 84  85.66  83.12   88.2        NaN
# 85  92.31  88.68  95.94        NaN
# 86  85.15  82.45  87.85        NaN
# 87  79.82  75.07  84.57        NaN
# 88  88.95  85.97  91.93        NaN
# 89  74.61     68  81.22        NaN
# 90  62.44  60.74  64.14        NaN

# %%
df_men.ix['0','Fruit Type']= 'Apples'

# %%
df_men = df_men.drop(df_men.index[-1])

# %%
df_men = df_men.drop('Fruit Type', 1)

# %%
print(df_men)
# Out:
#    Fruit Type   Mean  Lower  Upper   80
# 78      Apple  89.18  86.79  91.57  NaN
# 80      Apple  95.42  93.98  96.86  NaN
# 81      Apple  84.21  80.33  88.09  NaN
# 82      Apple  88.79  86.14  91.44  NaN
# 83      Apple  80.74  75.26  86.22  NaN
# 84      Apple  85.66  83.12   88.2  NaN
# 85      Apple  92.31  88.68  95.94  NaN
# 86      Apple  85.15  82.45  87.85  NaN
# 87      Apple  79.82  75.07  84.57  NaN
# 88      Apple  88.95  85.97  91.93  NaN
# 89      Apple  74.61     68  81.22  NaN
# 90      Apple  62.44  60.74  64.14  NaN

# %%
df_men.insert(0,'Fruit Type','Apple','Bananas')

# %%
df_men.ix['Fruit Type','80']='Bananas'

# %%
df_men = df_men.drop(df_men.index[-1])

# %%
df_men = df_men.drop('80', 1)

# %%
print(df_men)
# Out:
#    Fruit Type   Mean  Lower  Upper
# 78      Apple  89.18  86.79  91.57
# 80      Apple  95.42  93.98  96.86
# 81      Apple  84.21  80.33  88.09
# 82      Apple  88.79  86.14  91.44
# 83      Apple  80.74  75.26  86.22
# 84      Apple  85.66  83.12   88.2
# 85      Apple  92.31  88.68  95.94
# 86      Apple  85.15  82.45  87.85
# 87      Apple  79.82  75.07  84.57
# 88      Apple  88.95  85.97  91.93
# 89      Apple  74.61     68  81.22
# 90      Apple  62.44  60.74  64.14

# %%
df_men.set_value(1,0,'Bananas',True)
# Out:
# 78      Apple
# 80    Bananas
# 81      Apple
# 82      Apple
# 83      Apple
# 84      Apple
# 85      Apple
# 86      Apple
# 87      Apple
# 88      Apple
# 89      Apple
# 90      Apple
# Name: Fruit Type, dtype: object

# %%
print(df_men)
# Out:
#    Fruit Type   Mean  Lower  Upper
# 78      Apple  89.18  86.79  91.57
# 80    Bananas  95.42  93.98  96.86
# 81      Apple  84.21  80.33  88.09
# 82      Apple  88.79  86.14  91.44
# 83      Apple  80.74  75.26  86.22
# 84      Apple  85.66  83.12   88.2
# 85      Apple  92.31  88.68  95.94
# 86      Apple  85.15  82.45  87.85
# 87      Apple  79.82  75.07  84.57
# 88      Apple  88.95  85.97  91.93
# 89      Apple  74.61     68  81.22
# 90      Apple  62.44  60.74  64.14

# %%
df_men.set_value(5,0,'Melons',True)
# Out:
# 78      Apple
# 80    Bananas
# 81    Berries
# 82     Grapes
# 83      Apple
# 84     Melons
# 85      Apple
# 86      Apple
# 87      Apple
# 88      Apple
# 89      Apple
# 90      Apple
# Name: Fruit Type, dtype: object

# %%
df_men
# Out:
#    Fruit Type   Mean  Lower  Upper
# 78      Apple  89.18  86.79  91.57
# 80    Bananas  95.42  93.98  96.86
# 81    Berries  84.21  80.33  88.09
# 82     Grapes  88.79  86.14  91.44
# 83      Apple  80.74  75.26  86.22
# 84     Melons  85.66  83.12   88.2
# 85      Apple  92.31  88.68  95.94
# 86      Apple  85.15  82.45  87.85
# 87      Apple  79.82  75.07  84.57
# 88      Apple  88.95  85.97  91.93
# 89      Apple  74.61     68  81.22
# 90      Apple  62.44  60.74  64.14

# %%
df_men.set_value(4,0,'Melons',True)
df_men.set_value(5,0,'Oranges',True)
# Out:
# 78      Apple
# 80    Bananas
# 81    Berries
# 82     Grapes
# 83     Melons
# 84    Oranges
# 85      Apple
# 86      Apple
# 87      Apple
# 88      Apple
# 89      Apple
# 90      Apple
# Name: Fruit Type, dtype: object

# %%
df_men.set_value(6,0,'Other Citrus',True)
df_men.set_value(7,0,'Stone fruit',True)
df_men.set_value(8,0,'Tropical fruit',True)
# Out:
# 78             Apple
# 80           Bananas
# 81           Berries
# 82            Grapes
# 83            Melons
# 84           Oranges
# 85      Other Citrus
# 86       Stone fruit
# 87    Tropical fruit
# 88             Apple
# 89             Apple
# 90             Apple
# Name: Fruit Type, dtype: object

# %%
df_men
# Out:
#         Fruit Type   Mean  Lower  Upper
# 78           Apple  89.18  86.79  91.57
# 80         Bananas  95.42  93.98  96.86
# 81         Berries  84.21  80.33  88.09
# 82          Grapes  88.79  86.14  91.44
# 83          Melons  80.74  75.26  86.22
# 84         Oranges  85.66  83.12   88.2
# 85    Other Citrus  92.31  88.68  95.94
# 86     Stone fruit  85.15  82.45  87.85
# 87  Tropical fruit  79.82  75.07  84.57
# 88           Apple  88.95  85.97  91.93
# 89           Apple  74.61     68  81.22
# 90           Apple  62.44  60.74  64.14

# %%
df_men = df_men.drop(df_men.index[6])

# %%
df_men
# Out:
#         Fruit Type   Mean  Lower  Upper
# 78           Apple  89.18  86.79  91.57
# 80         Bananas  95.42  93.98  96.86
# 81         Berries  84.21  80.33  88.09
# 82          Grapes  88.79  86.14  91.44
# 83          Melons  80.74  75.26  86.22
# 84         Oranges  85.66  83.12   88.2
# 87  Tropical fruit  79.82  75.07  84.57
# 88           Apple  88.95  85.97  91.93
# 89           Apple  74.61     68  81.22
# 90           Apple  62.44  60.74  64.14

# %%
df_men.set_value(6,0,'Other Citrus',True)
df_men.set_value(7,0,'Stone fruit',True)
df_men.set_value(8,0,'Tropical fruit',True)
# Out:
# 78             Apple
# 80           Bananas
# 81           Berries
# 82            Grapes
# 83            Melons
# 84           Oranges
# 87      Other Citrus
# 88       Stone fruit
# 89    Tropical fruit
# 90             Apple
# Name: Fruit Type, dtype: object

# %%
df_men
# Out:
#         Fruit Type   Mean  Lower  Upper
# 78           Apple  89.18  86.79  91.57
# 80         Bananas  95.42  93.98  96.86
# 81         Berries  84.21  80.33  88.09
# 82          Grapes  88.79  86.14  91.44
# 83          Melons  80.74  75.26  86.22
# 84         Oranges  85.66  83.12   88.2
# 87    Other Citrus  79.82  75.07  84.57
# 88     Stone fruit  88.95  85.97  91.93
# 89  Tropical fruit  74.61     68  81.22
# 90           Apple  62.44  60.74  64.14

# %%
df_men = df_men.drop(df_men.index[-1])

# %%
df_men
# Out:
#         Fruit Type   Mean  Lower  Upper
# 78           Apple  89.18  86.79  91.57
# 80         Bananas  95.42  93.98  96.86
# 81         Berries  84.21  80.33  88.09
# 82          Grapes  88.79  86.14  91.44
# 83          Melons  80.74  75.26  86.22
# 84         Oranges  85.66  83.12   88.2
# 87    Other Citrus  79.82  75.07  84.57
# 88     Stone fruit  88.95  85.97  91.93
# 89  Tropical fruit  74.61     68  81.22

# %%
df_men = df_men.drop('Lower', 1)
df_men = df_men.drop('Upper', 1)

# %%
df_men
# Out:
#         Fruit Type   Mean
# 78           Apple  89.18
# 80         Bananas  95.42
# 81         Berries  84.21
# 82          Grapes  88.79
# 83          Melons  80.74
# 84         Oranges  85.66
# 87    Other Citrus  79.82
# 88     Stone fruit  88.95
# 89  Tropical fruit  74.61

# %%
df_test = df_men

# %%
df_men = df_men.reset_index(drop=True)

# %%
df_men
# Out:
#        Fruit Type   Mean
# 0           Apple  89.18
# 1         Bananas  95.42
# 2         Berries  84.21
# 3          Grapes  88.79
# 4          Melons  80.74
# 5         Oranges  85.66
# 6    Other Citrus  79.82
# 7     Stone fruit  88.95
# 8  Tropical fruit  74.61

# %%
df_men.columns = ['Fruit Type', 'Mean (94-98)']

# %%
df_men
# Out:
#        Fruit Type Mean (94-98)
# 0           Apple        89.18
# 1         Bananas        95.42
# 2         Berries        84.21
# 3          Grapes        88.79
# 4          Melons        80.74
# 5         Oranges        85.66
# 6    Other Citrus        79.82
# 7     Stone fruit        88.95
# 8  Tropical fruit        74.61

# %%
df_men3 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='05-06 FAH')

# %%
df_men2
# Out:
#     Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                          Total fruit
# 6                                        Apples, Total
# 7                                      Apples as fruit
# 8                                          Apple juice
# 9                                              Bananas
# 10                                             Berries
# 11                                              Grapes
# 12                                              Melons
# 13                                      Oranges, Total
# 14                                    Oranges as fruit
# ...

# %%
df_men2[70:100]
# Out:
#    Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 70  Appendix Table B-3 (cont'd).  LAFA at-home sha...
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                        Total fruit
# 77                                      Apples, Total
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# ...

# %%
df_men2=df_men2[77:90]

# %%
df_men2
# Out:
#    Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 77                                      Apples, Total
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 77      86.79      84.16      89.42      89.09      86.72      91.46
# ...

# %%
df_men2 = df_men2.drop('Unnamed: 8', 1)
df_men2 = df_men2.drop('Unnamed: 9', 1)
df_men2 = df_men2.drop('Unnamed: 10', 1)
df_men2 = df_men2.drop('Unnamed: 11', 1)
df_men2 = df_men2.drop('Unnamed: 12', 1)
df_men2 = df_men2.drop('Unnamed: 13', 1)
df_men2 = df_men2.drop('Unnamed: 14', 1)
df_men2 = df_men2.drop('Unnamed: 15', 1)

# %%
df_men2
# Out:
#    Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 0                                       Apples, Total
# 1                                     Apples as fruit
# 2                                         Apple juice
# 3                                             Bananas
# 4                                             Berries
# 5                                              Grapes
# 6                                              Melons
# 7                                      Oranges, Total
# 8                                    Oranges as fruit
# 9                                        Orange juice
# 10                                 Other citrus fruit
# 11                                        Stone fruit
# 12                                     Tropical fruit
#
#    Unnamed: 7
# 0       90.02
# 1       90.86
# 2       88.91
# 3       94.85
# 4       88.57
# 5       88.55
# 6       79.72
# 7       84.46
# ...

# %%
df_men2 = df_men2.reset_index(drop=True)

# %%
df_men2
# Out:
#    Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 0                                       Apples, Total
# 1                                     Apples as fruit
# 2                                         Apple juice
# 3                                             Bananas
# 4                                             Berries
# 5                                              Grapes
# 6                                              Melons
# 7                                      Oranges, Total
# 8                                    Oranges as fruit
# 9                                        Orange juice
# 10                                 Other citrus fruit
# 11                                        Stone fruit
# 12                                     Tropical fruit
#
#    Unnamed: 7
# 0       90.02
# 1       90.86
# 2       88.91
# 3       94.85
# 4       88.57
# 5       88.55
# 6       79.72
# 7       84.46
# ...

# %%
df_men2.columns = ['Fruit Types', 'Mean(03-04)']

# %%
df_men2
# Out:
#               Fruit Types Mean(03-04)
# 0           Apples, Total       90.02
# 1         Apples as fruit       90.86
# 2             Apple juice       88.91
# 3                 Bananas       94.85
# 4                 Berries       88.57
# 5                  Grapes       88.55
# 6                  Melons       79.72
# 7          Oranges, Total       84.46
# 8        Oranges as fruit       94.62
# 9            Orange juice       83.92
# 10     Other citrus fruit       73.74
# 11            Stone fruit       94.02
# 12         Tropical fruit       74.58

# %%
df_men2
# Out:
#               Fruit Types Mean(03-04)
# 0           Apples, Total       90.02
# 1         Apples as fruit       90.86
# 2             Apple juice       88.91
# 3                 Bananas       94.85
# 4                 Berries       88.57
# 5                  Grapes       88.55
# 6                  Melons       79.72
# 7          Oranges, Total       84.46
# 8        Oranges as fruit       94.62
# 9            Orange juice       83.92
# 10     Other citrus fruit       73.74
# 11            Stone fruit       94.02
# 12         Tropical fruit       74.58

# %%
df_men2 = df_men2.drop(df_men.index[0])
df_men2 = df_men2.reset_index(drop=True)

# %%
df_men2
# Out:
#               Fruit Types Mean(03-04)
# 0         Apples as fruit       90.86
# 1             Apple juice       88.91
# 2                 Bananas       94.85
# 3                 Berries       88.57
# 4                  Grapes       88.55
# 5                  Melons       79.72
# 6          Oranges, Total       84.46
# 7        Oranges as fruit       94.62
# 8            Orange juice       83.92
# 9      Other citrus fruit       73.74
# 10            Stone fruit       94.02
# 11         Tropical fruit       74.58

# %%
df_men2 = df_men2.drop(df_men.index[1])
df_men2 = df_men2.drop(df_men.index[7])
df_men2 = df_men2.drop(df_men.index[8])
df_men2 = df_men2.reset_index(drop=True)
df_men2
# Out:
#              Fruit Types Mean(03-04)
# 0        Apples as fruit       90.86
# 1                Bananas       94.85
# 2                Berries       88.57
# 3                 Grapes       88.55
# 4                 Melons       79.72
# 5         Oranges, Total       84.46
# 6     Other citrus fruit       73.74
# 7            Stone fruit       94.02
# 8         Tropical fruit       74.58

# %%
df_men
# Out:
#        Fruit Type Mean (94-98)
# 0           Apple        89.18
# 1         Bananas        95.42
# 2         Berries        84.21
# 3          Grapes        88.79
# 4          Melons        80.74
# 5         Oranges        85.66
# 6    Other Citrus        79.82
# 7     Stone fruit        88.95
# 8  Tropical fruit        74.61

# %%
df_test = df_test.reset_index(drop=True)

# %%
df_test.join(df_men2)
# Out:
#        Fruit Type   Mean            Fruit Types Mean(03-04)
# 0           Apple  89.18        Apples as fruit       90.86
# 1         Bananas  95.42                Bananas       94.85
# 2         Berries  84.21                Berries       88.57
# 3          Grapes  88.79                 Grapes       88.55
# 4          Melons  80.74                 Melons       79.72
# 5         Oranges  85.66         Oranges, Total       84.46
# 6    Other Citrus  79.82     Other citrus fruit       73.74
# 7     Stone fruit  88.95            Stone fruit       94.02
# 8  Tropical fruit  74.61         Tropical fruit       74.58

# %%
df_men = df_men.join(df_men2)

# %%
df_men = df_men.drop('Fruit Type', 1)

# %%
cols = df_men.columns.tolist()

# %%
cols
# Out:
# ['Mean (94-98)', 'Fruit Types', 'Mean(03-04)']

# %%
cols = cols[-1:]+cols[:-1]

# %%
cols
# Out:
# ['Mean(03-04)', 'Mean (94-98)', 'Fruit Types']

# %%
cols = cols[-1:]+cols[:-1]
cols
# Out:
# ['Fruit Types', 'Mean(03-04)', 'Mean (94-98)']

# %%
cols[1],cols[2]=cols[2],cols[1]

# %%
cols
# Out:
# ['Fruit Types', 'Mean (94-98)', 'Mean(03-04)']

# %%
df_men=df_men[cols]

# %%
df_men
# Out:
#              Fruit Types Mean (94-98) Mean(03-04)
# 0        Apples as fruit        89.18       90.86
# 1                Bananas        95.42       94.85
# 2                Berries        84.21       88.57
# 3                 Grapes        88.79       88.55
# 4                 Melons        80.74       79.72
# 5         Oranges, Total        85.66       84.46
# 6     Other citrus fruit        79.82       73.74
# 7            Stone fruit        88.95       94.02
# 8         Tropical fruit        74.61       74.58

# %%
df_men3 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='05-06 FAH')

# %%
df_men3 = df_men3[78:90]

# %%
df_men3
# Out:
#    Appendix Table B-5.  LAFA at-home shares: 2005-06 means and confidence intervals for U.S., children, and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 78      80.69      75.91      85.47      85.88      81.68      90.08
# ...

# %%
df_men3 = df_men3.drop('Unnamed: 1', 1)
df_men3 = df_men3.drop('Unnamed: 2', 1)
df_men3 = df_men3.drop('Unnamed: 3', 1)
df_men3 = df_men3.drop('Unnamed: 4', 1)
df_men3 = df_men3.drop('Unnamed: 5', 1)
df_men3 = df_men3.drop('Unnamed: 6', 1)
df_men3 = df_men3.drop('Unnamed: 8', 1)
df_men3 = df_men3.drop('Unnamed: 9', 1)
df_men3 = df_men3.drop('Unnamed: 10', 1)
df_men3 = df_men3.drop('Unnamed: 11', 1)
df_men3 = df_men3.drop('Unnamed: 12', 1)
df_men3 = df_men3.drop('Unnamed: 13', 1)
df_men3 = df_men3.drop('Unnamed: 14', 1)
df_men3 = df_men3.drop('Unnamed: 15', 1)

# %%
df_men3
# Out:
#    Appendix Table B-5.  LAFA at-home shares: 2005-06 means and confidence intervals for U.S., children, and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 7
# 78       89.7
# 79         93
# 80      95.59
# 81      91.83
# 82      93.65
# 83      80.85
# 84         86
# 85      94.49
# 86      85.52
# 87      72.95
# 88      93.05
# ...

# %%
df_men3 = df_men3.drop(0, 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-be63b86a9a28> in <module>()
# ----> 1 df_men3 = df_men3.drop(0, 1)
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
# ...

# %%
df_men3.columns = ['Fruit Types', 'Mean(05-06)']

# %%
df_men3
# Out:
#               Fruit Types Mean(05-06)
# 78        Apples as fruit        89.7
# 79            Apple juice          93
# 80                Bananas       95.59
# 81                Berries       91.83
# 82                 Grapes       93.65
# 83                 Melons       80.85
# 84         Oranges, Total          86
# 85       Oranges as fruit       94.49
# 86           Orange juice       85.52
# 87     Other citrus fruit       72.95
# 88            Stone fruit       93.05
# 89         Tropical fruit       76.94

# %%
df_men3 = df_men3.drop('Fruit Types', 1)

# %%
df_men3
# Out:
#    Mean(05-06)
# 78        89.7
# 79          93
# 80       95.59
# 81       91.83
# 82       93.65
# 83       80.85
# 84          86
# 85       94.49
# 86       85.52
# 87       72.95
# 88       93.05
# 89       76.94

# %%
df_men3 = df_men3.reset_index(drop=True)

# %% [markdown]
# df_men3

# %%
df_men3
# Out:
#    Mean(05-06)
# 0         89.7
# 1           93
# 2        95.59
# 3        91.83
# 4        93.65
# 5        80.85
# 6           86
# 7        94.49
# 8        85.52
# 9        72.95
# 10       93.05
# 11       76.94

# %%
df_men.join(df_men3)
# Out:
#              Fruit Types Mean (94-98) Mean(03-04) Mean(05-06)
# 0        Apples as fruit        89.18       90.86        89.7
# 1                Bananas        95.42       94.85          93
# 2                Berries        84.21       88.57       95.59
# 3                 Grapes        88.79       88.55       91.83
# 4                 Melons        80.74       79.72       93.65
# 5         Oranges, Total        85.66       84.46       80.85
# 6     Other citrus fruit        79.82       73.74          86
# 7            Stone fruit        88.95       94.02       94.49
# 8         Tropical fruit        74.61       74.58       85.52

# %%
df_men3 = df_men3.drop(df_men.index[1])
df_men3 = df_men3.drop(df_men.index[7])
df_men3 = df_men3.drop(df_men.index[8])
df_men3 = df_men3.reset_index(drop=True)
df_men3
# Out:
#   Mean(05-06)
# 0        89.7
# 1       95.59
# 2       91.83
# 3       93.65
# 4       80.85
# 5          86
# 6       72.95
# 7       93.05
# 8       76.94

# %%
df_men = df_men.join(df_men3)

# %% [markdown]
# df_men

# %%
df_men
# Out:
#              Fruit Types Mean (94-98) Mean(03-04) Mean(05-06)
# 0        Apples as fruit        89.18       90.86        89.7
# 1                Bananas        95.42       94.85       95.59
# 2                Berries        84.21       88.57       91.83
# 3                 Grapes        88.79       88.55       93.65
# 4                 Melons        80.74       79.72       80.85
# 5         Oranges, Total        85.66       84.46          86
# 6     Other citrus fruit        79.82       73.74       72.95
# 7            Stone fruit        88.95       94.02       93.05
# 8         Tropical fruit        74.61       74.58       76.94

# %%
df_men4 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='07-08 FAH')

# %%
df_men4 = df_men4[78:90]

# %%
df_men4
# Out:
#    Appendix Table B-7.  LAFA at-home shares: 2007-08 means and confidence intervals for U.S., children, and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 78       79.7      75.22      84.18      85.33      81.91      88.75
# ...

# %%
for i in range(1,16):
    if i != 7:
        df_men4 = df_men4.drop('Unnamed: ' + str(i), 1)
        i+1

# %%
df_men4
# Out:
#    Appendix Table B-7.  LAFA at-home shares: 2007-08 means and confidence intervals for U.S., children, and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 7
# 78      93.35
# 79      92.13
# 80      93.96
# 81       90.7
# 82      92.16
# 83      84.97
# 84      84.16
# 85      92.17
# 86      83.49
# 87       61.9
# 88      95.89
# ...

# %%
df_men4 = df_men4.reset_index(drop=True)
df_men4 = df_men4.drop(df_men.index[1])
df_men4 = df_men4.drop(df_men.index[7])
df_men4 = df_men4.drop(df_men.index[8])
df_men4 = df_men4.reset_index(drop=True)
df_men3
# Out:
#   Mean(05-06)
# 0        89.7
# 1       95.59
# 2       91.83
# 3       93.65
# 4       80.85
# 5          86
# 6       72.95
# 7       93.05
# 8       76.94

# %%
df_men4
# Out:
#   Appendix Table B-7.  LAFA at-home shares: 2007-08 means and confidence intervals for U.S., children, and adults  \
# 0                                    Apples as fruit
# 1                                            Bananas
# 2                                            Berries
# 3                                             Grapes
# 4                                             Melons
# 5                                     Oranges, Total
# 6                                 Other citrus fruit
# 7                                        Stone fruit
# 8                                     Tropical fruit
#
#   Unnamed: 7
# 0      93.35
# 1      93.96
# 2       90.7
# 3      92.16
# 4      84.97
# 5      84.16
# 6       61.9
# 7      95.89
# 8      84.68

# %%
df_men4.columns['Fruit types','Mean (07-08)']
# Out:
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py:1275: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   result = getitem(key)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-226-b76d740e08ef> in <module>()
# ----> 1 df_men4.columns['Fruit types','Mean (07-08)']
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in __getitem__(self, key)
#    1273
#    1274         key = _values_from_object(key)
# -> 1275         result = getitem(key)
#    1276         if not lib.isscalar(result):
#    1277             return promote(result)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df_men3.columns = ['Fruit Types', 'Mean(07-08)']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-227-ae4c600652f6> in <module>()
# ----> 1 df_men3.columns = ['Fruit Types', 'Mean(07-08)']
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    2683         try:
#    2684             object.__getattribute__(self, name)
# -> 2685             return object.__setattr__(self, name, value)
#    2686         except AttributeError:
#    2687             pass
#
# pandas/src/properties.pyx in pandas.lib.AxisProperty.__set__ (pandas/lib.c:44748)()
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     426
#     427     def _set_axis(self, axis, labels):
# --> 428         self._data.set_axis(axis, labels)
#     429         self._clear_item_cache()
#     430
#
# ...

# %%
df_men4.columns = ['Fruit Types', 'Mean(05-06)']

# %%
df_men4
# Out:
#              Fruit Types Mean(05-06)
# 0        Apples as fruit       93.35
# 1                Bananas       93.96
# 2                Berries        90.7
# 3                 Grapes       92.16
# 4                 Melons       84.97
# 5         Oranges, Total       84.16
# 6     Other citrus fruit        61.9
# 7            Stone fruit       95.89
# 8         Tropical fruit       84.68

# %%
df_men.join(df_men4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-230-2c48ba0a3538> in <module>()
# ----> 1 df_men.join(df_men4)
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4383         # For SparseDataFrame's benefit
#    4384         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4385                                  rsuffix=rsuffix, sort=sort)
#    4386
#    4387     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4397             return merge(self, other, left_on=on, how=how,
#    4398                          left_index=on is None, right_index=True,
# ...

# %%
df_men
# Out:
#              Fruit Types Mean (94-98) Mean(03-04) Mean(05-06)
# 0        Apples as fruit        89.18       90.86        89.7
# 1                Bananas        95.42       94.85       95.59
# 2                Berries        84.21       88.57       91.83
# 3                 Grapes        88.79       88.55       93.65
# 4                 Melons        80.74       79.72       80.85
# 5         Oranges, Total        85.66       84.46          86
# 6     Other citrus fruit        79.82       73.74       72.95
# 7            Stone fruit        88.95       94.02       93.05
# 8         Tropical fruit        74.61       74.58       76.94

# %%
df_men4
# Out:
#              Fruit Types Mean(05-06)
# 0        Apples as fruit       93.35
# 1                Bananas       93.96
# 2                Berries        90.7
# 3                 Grapes       92.16
# 4                 Melons       84.97
# 5         Oranges, Total       84.16
# 6     Other citrus fruit        61.9
# 7            Stone fruit       95.89
# 8         Tropical fruit       84.68

# %%
df_men4 = df_men4.drop('Fruit Types', 1)

# %%
df_men.join(df_men4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-234-2c48ba0a3538> in <module>()
# ----> 1 df_men.join(df_men4)
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4383         # For SparseDataFrame's benefit
#    4384         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4385                                  rsuffix=rsuffix, sort=sort)
#    4386
#    4387     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4397             return merge(self, other, left_on=on, how=how,
#    4398                          left_index=on is None, right_index=True,
# ...

# %%
df_men.join(df_men4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-235-2c48ba0a3538> in <module>()
# ----> 1 df_men.join(df_men4)
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4383         # For SparseDataFrame's benefit
#    4384         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4385                                  rsuffix=rsuffix, sort=sort)
#    4386
#    4387     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4397             return merge(self, other, left_on=on, how=how,
#    4398                          left_index=on is None, right_index=True,
# ...

# %%
df_men
# Out:
#              Fruit Types Mean (94-98) Mean(03-04) Mean(05-06)
# 0        Apples as fruit        89.18       90.86        89.7
# 1                Bananas        95.42       94.85       95.59
# 2                Berries        84.21       88.57       91.83
# 3                 Grapes        88.79       88.55       93.65
# 4                 Melons        80.74       79.72       80.85
# 5         Oranges, Total        85.66       84.46          86
# 6     Other citrus fruit        79.82       73.74       72.95
# 7            Stone fruit        88.95       94.02       93.05
# 8         Tropical fruit        74.61       74.58       76.94

# %%
df_men4
# Out:
#   Mean(05-06)
# 0       93.35
# 1       93.96
# 2        90.7
# 3       92.16
# 4       84.97
# 5       84.16
# 6        61.9
# 7       95.89
# 8       84.68

# %%
df_men4.columns=['Mean(07-08)']

# %%
df_men = df_men.join(df_men4)

# %%
df_men
# Out:
#              Fruit Types Mean (94-98) Mean(03-04) Mean(05-06) Mean(07-08)
# 0        Apples as fruit        89.18       90.86        89.7       93.35
# 1                Bananas        95.42       94.85       95.59       93.96
# 2                Berries        84.21       88.57       91.83        90.7
# 3                 Grapes        88.79       88.55       93.65       92.16
# 4                 Melons        80.74       79.72       80.85       84.97
# 5         Oranges, Total        85.66       84.46          86       84.16
# 6     Other citrus fruit        79.82       73.74       72.95        61.9
# 7            Stone fruit        88.95       94.02       93.05       95.89
# 8         Tropical fruit        74.61       74.58       76.94       84.68

# %%
df_men.plot(x='Fruit Types', y='Mean (94-98)')

# %%
df_transpose = df_men.transpose()

# %%
df_transpose
# Out:
#                    Apples as fruit     Bananas     Berries     Grapes  \
# Fruit Types        Apples as fruit     Bananas     Berries     Grapes
# Mean (94-98)                 89.18       95.42       84.21      88.79
# Mean(03-04)                  90.86       94.85       88.57      88.55
# Mean(05-06)                   89.7       95.59       91.83      93.65
# Mean(07-08)                  93.35       93.96        90.7      92.16
#
#                  Melons      Oranges,Total     Other citrus fruit  \
# Fruit Types      Melons     Oranges, Total     Other citrus fruit
# Mean (94-98)      80.74              85.66                  79.82
# Mean(03-04)       79.72              84.46                  73.74
# Mean(05-06)       80.85                 86                  72.95
# Mean(07-08)       84.97              84.16                   61.9
#
#                  Stone fruit     Tropical fruit
# Fruit Types      Stone fruit     Tropical fruit
# Mean (94-98)           88.95              74.61
# ...

# %%
df_transpose.columns=['Apples as fruit','Bananas','Berries','Grapes','Melons','Oranges,Total','Other citrus fruit','Stone fruit','Tropical fruit']

# %%
df_transpose = df_transpose[1:]

# %%
df_transpose
# Out:
#              Apples as fruit Bananas Berries Grapes Melons Oranges,Total  \
# Mean (94-98)           89.18   95.42   84.21  88.79  80.74         85.66
# Mean(03-04)            90.86   94.85   88.57  88.55  79.72         84.46
# Mean(05-06)             89.7   95.59   91.83  93.65  80.85            86
# Mean(07-08)            93.35   93.96    90.7  92.16  84.97         84.16
#
#              Other citrus fruit Stone fruit Tropical fruit
# Mean (94-98)              79.82       88.95          74.61
# Mean(03-04)               73.74       94.02          74.58
# Mean(05-06)               72.95       93.05          76.94
# Mean(07-08)                61.9       95.89          84.68

# %%
df_men.columns=['Fruit Types','94-98','03-04','05-06','07-08']

# %%
df_men
# Out:
#              Fruit Types  94-98  03-04  05-06  07-08
# 0        Apples as fruit  89.18  90.86   89.7  93.35
# 1                Bananas  95.42  94.85  95.59  93.96
# 2                Berries  84.21  88.57  91.83   90.7
# 3                 Grapes  88.79  88.55  93.65  92.16
# 4                 Melons  80.74  79.72  80.85  84.97
# 5         Oranges, Total  85.66  84.46     86  84.16
# 6     Other citrus fruit  79.82  73.74  72.95   61.9
# 7            Stone fruit  88.95  94.02  93.05  95.89
# 8         Tropical fruit  74.61  74.58  76.94  84.68

# %%
df_men.transpose
# Out:
#              Apples as fruit Bananas Berries Grapes Melons Oranges,Total  \
# Mean (94-98)           89.18   95.42   84.21  88.79  80.74         85.66
# Mean(03-04)            90.86   94.85   88.57  88.55  79.72         84.46
# Mean(05-06)             89.7   95.59   91.83  93.65  80.85            86
# Mean(07-08)            93.35   93.96    90.7  92.16  84.97         84.16
#
#              Other citrus fruit Stone fruit Tropical fruit
# Mean (94-98)              79.82       88.95          74.61
# Mean(03-04)               73.74       94.02          74.58
# Mean(05-06)               72.95       93.05          76.94
# Mean(07-08)                61.9       95.89          84.68

# %%
df_transpose2 = df_men.transpose()

# %%
df_transpose2.columns=['Apples as fruit','Bananas','Berries','Grapes','Melons','Oranges,total','Other citrus fruit','Stone fruit','Tropical fruit']

# %%
df_transpose.plot()

# %%
df_transpose2
# Out:
#                   Apples as fruit     Bananas     Berries     Grapes  \
# Fruit Types       Apples as fruit     Bananas     Berries     Grapes
# 94-98                       89.18       95.42       84.21      88.79
# 03-04                       90.86       94.85       88.57      88.55
# 05-06                        89.7       95.59       91.83      93.65
# 07-08                       93.35       93.96        90.7      92.16
#
#                 Melons      Oranges,total     Other citrus fruit  \
# Fruit Types     Melons     Oranges, Total     Other citrus fruit
# 94-98            80.74              85.66                  79.82
# 03-04            79.72              84.46                  73.74
# 05-06            80.85                 86                  72.95
# 07-08            84.97              84.16                   61.9
#
#                 Stone fruit     Tropical fruit
# Fruit Types     Stone fruit     Tropical fruit
# 94-98                 88.95              74.61
# ...

# %%
styles1 = ['-','--','--','-.','-','-.','--','-.','-']
df_transpose.plot(style=styles1)
plt.ylabel('Average Percent')
plt.xlabel('Year')

# %%
df_transpose2
# Out:
#                   Apples as fruit     Bananas     Berries     Grapes  \
# Fruit Types       Apples as fruit     Bananas     Berries     Grapes
# 94-98                       89.18       95.42       84.21      88.79
# 03-04                       90.86       94.85       88.57      88.55
# 05-06                        89.7       95.59       91.83      93.65
# 07-08                       93.35       93.96        90.7      92.16
#
#                 Melons      Oranges,total     Other citrus fruit  \
# Fruit Types     Melons     Oranges, Total     Other citrus fruit
# 94-98            80.74              85.66                  79.82
# 03-04            79.72              84.46                  73.74
# 05-06            80.85                 86                  72.95
# 07-08            84.97              84.16                   61.9
#
#                 Stone fruit     Tropical fruit
# Fruit Types     Stone fruit     Tropical fruit
# 94-98                 88.95              74.61
# ...

# %%
df_transpose2 = df_transpose2[1:]

# %%
df_transpose2
# Out:
#       Apples as fruit Bananas Berries Grapes Melons Oranges,total  \
# 94-98           89.18   95.42   84.21  88.79  80.74         85.66
# 03-04           90.86   94.85   88.57  88.55  79.72         84.46
# 05-06            89.7   95.59   91.83  93.65  80.85            86
# 07-08           93.35   93.96    90.7  92.16  84.97         84.16
#
#       Other citrus fruit Stone fruit Tropical fruit
# 94-98              79.82       88.95          74.61
# 03-04              73.74       94.02          74.58
# 05-06              72.95       93.05          76.94
# 07-08               61.9       95.89          84.68

# %%
styles1 = ['-','--','--','-.','-','-.','--','-.','-']
df_transpose2.plot(style=styles1)
plt.ylabel('Average Percent')
plt.xlabel('Year')

# %%
styles1 = ['-','--','--','-.','-','-.','--','-.','-']
df_transpose2.plot(style=styles1)
plt.ylabel('Average Percent of at Home Fruit Consumption')
plt.xlabel('Year')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),ncol=3, fancybox=True, shadow=True)

# %% [markdown]
# Source: U.S. Food Commodity Availability by Food Source, 1994-2008
# https://www.ers.usda.gov/publications/pub-details/?pubid=81817
# Data: https://www.ers.usda.gov/webdocs/publications/err221/appendix%20b%20(shares).xls?v=42725
#
# From the figure above, we see that the percent of other citrus fruit consumed at home decreased by nearly 20% from 1994-2008. Meanwhile, tropical fruit saw the largest percent increase over that same time period.

# %%
df_women = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='94-98 FAH')

# %%
df_women
# Out:
#     Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                          Total fruit
# 6                                        Apples, Total
# 7                                      Apples as fruit
# 8                                          Apple juice
# 9                                              Bananas
# 10                                             Berries
# 11                                              Grapes
# 12                                              Melons
# 13                                      Oranges, Total
# 14                                    Oranges as fruit
# ...

# %%
for i in range(1,16):
    if i != 10:
        df_women = df_women.drop('Unnamed: ' + str(i), 1)
        i+1

# %%
df_women
# Out:
#     Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                          Total fruit
# 6                                        Apples, Total
# 7                                      Apples as fruit
# 8                                          Apple juice
# 9                                              Bananas
# 10                                             Berries
# 11                                              Grapes
# 12                                              Melons
# 13                                      Oranges, Total
# 14                                    Oranges as fruit
# ...

# %%
df_women = df_women[78:90]

# %%
df_women
# Out:
#    Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 10
# 78       90.42
# 79       88.42
# 80       94.18
# 81       81.73
# 82       88.13
# 83       84.96
# 84       89.77
# 85       93.96
# 86       89.42
# 87       80.64
# 88       89.55
# ...

# %%
#df_men2 = df_men2.drop(df_men.index[0])
df_women = df_women.reset_index(drop=True)

# %%
df_women
# Out:
#    Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 0                                     Apples as fruit
# 1                                         Apple juice
# 2                                             Bananas
# 3                                             Berries
# 4                                              Grapes
# 5                                              Melons
# 6                                      Oranges, Total
# 7                                    Oranges as fruit
# 8                                        Orange juice
# 9                                  Other citrus fruit
# 10                                        Stone fruit
# 11                                     Tropical fruit
#
#    Unnamed: 10
# 0        90.42
# 1        88.42
# 2        94.18
# 3        81.73
# 4        88.13
# 5        84.96
# 6        89.77
# 7        93.96
# 8        89.42
# 9        80.64
# 10       89.55
# ...

# %%
df_women = df_women.drop(df_women.index[1])

# %%
df_women = df_women.reset_index(drop=True)

# %%
df_women
# Out:
#    Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 0                                     Apples as fruit
# 1                                             Bananas
# 2                                             Berries
# 3                                              Grapes
# 4                                              Melons
# 5                                      Oranges, Total
# 6                                    Oranges as fruit
# 7                                        Orange juice
# 8                                  Other citrus fruit
# 9                                         Stone fruit
# 10                                     Tropical fruit
#
#    Unnamed: 10
# 0        90.42
# 1        94.18
# 2        81.73
# 3        88.13
# 4        84.96
# 5        89.77
# 6        93.96
# 7        89.42
# 8        80.64
# 9        89.55
# 10        80.4

# %%
df_women = df_women.drop(df_women.index[6])

# %%
df_women
# Out:
#   Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 0                                    Apples as fruit
# 1                                            Bananas
# 2                                            Berries
# 3                                             Grapes
# 4                                             Melons
# 5                                     Oranges, Total
# 6                                       Orange juice
# 7                                 Other citrus fruit
# 8                                        Stone fruit
# 9                                     Tropical fruit
#
#   Unnamed: 10
# 0       90.42
# 1       94.18
# 2       81.73
# 3       88.13
# 4       84.96
# 5       89.77
# 6       89.42
# 7       80.64
# 8       89.55
# 9        80.4

# %%
df_women = df_women.drop(df_women.index[6])

# %%
df_women
# Out:
#   Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 0                                    Apples as fruit
# 1                                            Bananas
# 2                                            Berries
# 3                                             Grapes
# 4                                             Melons
# 5                                     Oranges, Total
# 6                                 Other citrus fruit
# 7                                        Stone fruit
# 8                                     Tropical fruit
#
#   Unnamed: 10
# 0       90.42
# 1       94.18
# 2       81.73
# 3       88.13
# 4       84.96
# 5       89.77
# 6       80.64
# 7       89.55
# 8        80.4

# %%
df_women.columns = ['Fruit Types','94-98']

# %%
df_women
# Out:
#              Fruit Types  94-98
# 0        Apples as fruit  90.42
# 1                Bananas  94.18
# 2                Berries  81.73
# 3                 Grapes  88.13
# 4                 Melons  84.96
# 5         Oranges, Total  89.77
# 6     Other citrus fruit  80.64
# 7            Stone fruit  89.55
# 8         Tropical fruit   80.4

# %%
df_women4 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='07-08 FAH')

# %%
for i in range(1,16):
    if i != 10:
        df_women4 = df_women4.drop('Unnamed: ' + str(i), 1)
        i+1

# %%
df_women2
# Out:
#     Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                          Total fruit
# 6                                        Apples, Total
# 7                                      Apples as fruit
# 8                                          Apple juice
# 9                                              Bananas
# 10                                             Berries
# 11                                              Grapes
# 12                                              Melons
# 13                                      Oranges, Total
# 14                                    Oranges as fruit
# ...

# %%
df_women4=df_women4[78:90]

# %%
df_women2
# Out:
#    Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 10
# 78       91.21
# 79       87.75
# 80       94.57
# 81       88.29
# 82       90.14
# 83       80.99
# 84       88.07
# 85       92.33
# 86       87.74
# 87        69.6
# 88       87.94
# ...

# %%
df_women.columns = ['Fruit Types','94-98']

# %%
df_women2
# Out:
#    Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 10
# 78       91.21
# 79       87.75
# 80       94.57
# 81       88.29
# 82       90.14
# 83       80.99
# 84       88.07
# 85       92.33
# 86       87.74
# 87        69.6
# 88       87.94
# ...

# %%
#df_men2 = df_men2.drop(df_men.index[0])
df_women2 = df_women2.reset_index(drop=True)

# %%
df_women2
# Out:
#    Appendix Table B-3.  LAFA at-home shares: 2003-04 means and confidence intervals for U.S. children and adults  \
# 0                                     Apples as fruit
# 1                                         Apple juice
# 2                                             Bananas
# 3                                             Berries
# 4                                              Grapes
# 5                                              Melons
# 6                                      Oranges, Total
# 7                                    Oranges as fruit
# 8                                        Orange juice
# 9                                  Other citrus fruit
# 10                                        Stone fruit
# 11                                     Tropical fruit
#
#    Unnamed: 10
# 0        91.21
# 1        87.75
# 2        94.57
# 3        88.29
# 4        90.14
# 5        80.99
# 6        88.07
# 7        92.33
# 8        87.74
# 9         69.6
# 10       87.94
# ...

# %%
df_women2.columns=['Fuit Types','03-04']

# %%
df_women2
# Out:
#                Fuit Types  03-04
# 0         Apples as fruit  91.21
# 1             Apple juice  87.75
# 2                 Bananas  94.57
# 3                 Berries  88.29
# 4                  Grapes  90.14
# 5                  Melons  80.99
# 6          Oranges, Total  88.07
# 7        Oranges as fruit  92.33
# 8            Orange juice  87.74
# 9      Other citrus fruit   69.6
# 10            Stone fruit  87.94
# 11         Tropical fruit  85.85

# %%
df_women
# Out:
#              Fruit Types  94-98
# 0        Apples as fruit  90.42
# 1                Bananas  94.18
# 2                Berries  81.73
# 3                 Grapes  88.13
# 4                 Melons  84.96
# 5         Oranges, Total  89.77
# 6     Other citrus fruit  80.64
# 7            Stone fruit  89.55
# 8         Tropical fruit   80.4

# %%
df_women2 = df_women2.drop(df_women.index[6])
df_women2 = df_women2.reset_index(drop=True)

# %%
df_women2
# Out:
#               Fuit Types  03-04
# 0        Apples as fruit  91.21
# 1                Bananas  94.57
# 2                Berries  88.29
# 3                 Grapes  90.14
# 4                 Melons  80.99
# 5         Oranges, Total  88.07
# 6     Other citrus fruit   69.6
# 7            Stone fruit  87.94
# 8         Tropical fruit  85.85

# %%
df_women = df_women.join(df_women2)

# %%
df_women2=df_women2.drop('Fuit Types',1)

# %%
df_women
# Out:
#              Fruit Types  94-98  03-04
# 0        Apples as fruit  90.42  91.21
# 1                Bananas  94.18  94.57
# 2                Berries  81.73  88.29
# 3                 Grapes  88.13  90.14
# 4                 Melons  84.96  80.99
# 5         Oranges, Total  89.77  88.07
# 6     Other citrus fruit  80.64   69.6
# 7            Stone fruit  89.55  87.94
# 8         Tropical fruit   80.4  85.85

# %%
df_women3
# Out:
#    Appendix Table B-5.  LAFA at-home shares: 2005-06 means and confidence intervals for U.S., children, and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 10
# 78        91.5
# 79       87.77
# 80       93.67
# 81       90.92
# 82       91.33
# 83       93.57
# 84       88.86
# 85       93.15
# 86       88.42
# 87       75.13
# 88       89.61
# ...

# %%
#df_women2 = df_women2.drop(df_women.index[6])
df_women3 = df_women3.reset_index(drop=True)

# %%
df_women3
# Out:
#    Appendix Table B-5.  LAFA at-home shares: 2005-06 means and confidence intervals for U.S., children, and adults  \
# 0                                     Apples as fruit
# 1                                         Apple juice
# 2                                             Bananas
# 3                                             Berries
# 4                                              Grapes
# 5                                              Melons
# 6                                      Oranges, Total
# 7                                    Oranges as fruit
# 8                                        Orange juice
# 9                                  Other citrus fruit
# 10                                        Stone fruit
# 11                                     Tropical fruit
#
#    Unnamed: 10
# 0         91.5
# 1        87.77
# 2        93.67
# 3        90.92
# 4        91.33
# 5        93.57
# 6        88.86
# 7        93.15
# 8        88.42
# 9        75.13
# 10       89.61
# ...

# %%
df_women3 = df_women3.drop(df_women.index[1])
df_women3 = df_women3.reset_index(drop=True)

# %%
df_women3
# Out:
#    Appendix Table B-5.  LAFA at-home shares: 2005-06 means and confidence intervals for U.S., children, and adults  \
# 0                                     Apples as fruit
# 1                                             Bananas
# 2                                             Berries
# 3                                              Grapes
# 4                                              Melons
# 5                                      Oranges, Total
# 6                                    Oranges as fruit
# 7                                        Orange juice
# 8                                  Other citrus fruit
# 9                                         Stone fruit
# 10                                     Tropical fruit
#
#    Unnamed: 10
# 0         91.5
# 1        93.67
# 2        90.92
# 3        91.33
# 4        93.57
# 5        88.86
# 6        93.15
# 7        88.42
# 8        75.13
# 9        89.61
# 10       76.57

# %%
df_women3 = df_women3.drop(df_women.index[6])
df_women3 = df_women3.reset_index(drop=True)

# %%
df_women3
# Out:
#   Appendix Table B-5.  LAFA at-home shares: 2005-06 means and confidence intervals for U.S., children, and adults  \
# 0                                    Apples as fruit
# 1                                            Bananas
# 2                                            Berries
# 3                                             Grapes
# 4                                             Melons
# 5                                     Oranges, Total
# 6                                       Orange juice
# 7                                 Other citrus fruit
# 8                                        Stone fruit
# 9                                     Tropical fruit
#
#   Unnamed: 10
# 0        91.5
# 1       93.67
# 2       90.92
# 3       91.33
# 4       93.57
# 5       88.86
# 6       88.42
# 7       75.13
# 8       89.61
# 9       76.57

# %%
df_women3 = df_women3.drop(df_women.index[6])
df_women3 = df_women3.reset_index(drop=True)

# %%
df_women3
# Out:
#   Appendix Table B-5.  LAFA at-home shares: 2005-06 means and confidence intervals for U.S., children, and adults  \
# 0                                    Apples as fruit
# 1                                            Bananas
# 2                                            Berries
# 3                                             Grapes
# 4                                             Melons
# 5                                     Oranges, Total
# 6                                 Other citrus fruit
# 7                                        Stone fruit
# 8                                     Tropical fruit
#
#   Unnamed: 10
# 0        91.5
# 1       93.67
# 2       90.92
# 3       91.33
# 4       93.57
# 5       88.86
# 6       75.13
# 7       89.61
# 8       76.57

# %%
df_women3.columns=['f','05-06']

# %%
df_women3
# Out:
#                        f  05-06
# 0        Apples as fruit   91.5
# 1                Bananas  93.67
# 2                Berries  90.92
# 3                 Grapes  91.33
# 4                 Melons  93.57
# 5         Oranges, Total  88.86
# 6     Other citrus fruit  75.13
# 7            Stone fruit  89.61
# 8         Tropical fruit  76.57

# %%
df_women3 = df_women3.drop('f',1)

# %%
df_women3
# Out:
#    05-06
# 0   91.5
# 1  93.67
# 2  90.92
# 3  91.33
# 4  93.57
# 5  88.86
# 6  75.13
# 7  89.61
# 8  76.57

# %%
df_women = df_women.join(df_women3)

# %%
df_women
# Out:
#              Fruit Types  94-98  03-04  05-06
# 0        Apples as fruit  90.42  91.21   91.5
# 1                Bananas  94.18  94.57  93.67
# 2                Berries  81.73  88.29  90.92
# 3                 Grapes  88.13  90.14  91.33
# 4                 Melons  84.96  80.99  93.57
# 5         Oranges, Total  89.77  88.07  88.86
# 6     Other citrus fruit  80.64   69.6  75.13
# 7            Stone fruit  89.55  87.94  89.61
# 8         Tropical fruit   80.4  85.85  76.57

# %%
df_women4
# Out:
#    Appendix Table B-7.  LAFA at-home shares: 2007-08 means and confidence intervals for U.S., children, and adults  \
# 78                                    Apples as fruit
# 79                                        Apple juice
# 80                                            Bananas
# 81                                            Berries
# 82                                             Grapes
# 83                                             Melons
# 84                                     Oranges, Total
# 85                                   Oranges as fruit
# 86                                       Orange juice
# 87                                 Other citrus fruit
# 88                                        Stone fruit
# 89                                     Tropical fruit
#
#    Unnamed: 10
# 78       91.69
# 79       87.67
# 80        94.2
# 81       87.99
# 82       90.02
# 83       85.48
# 84       89.35
# 85       96.57
# 86       88.69
# 87       77.85
# 88        94.3
# ...

# %%
df_women4.columns=['f','07-08']

# %%
#df_women3 = df_women3.drop(df_women.index[6])
df_women4 = df_women4.reset_index(drop=True)

# %%
df_women4
# Out:
#                         f  07-08
# 0         Apples as fruit  91.69
# 1             Apple juice  87.67
# 2                 Bananas   94.2
# 3                 Berries  87.99
# 4                  Grapes  90.02
# 5                  Melons  85.48
# 6          Oranges, Total  89.35
# 7        Oranges as fruit  96.57
# 8            Orange juice  88.69
# 9      Other citrus fruit  77.85
# 10            Stone fruit   94.3
# 11         Tropical fruit  80.72

# %%
df_women4 = df_women4.drop(df_women4.index[1])
df_women4 = df_women4.reset_index(drop=True)

# %%
df_women4
# Out:
#                         f  07-08
# 0         Apples as fruit  91.69
# 1                 Bananas   94.2
# 2                 Berries  87.99
# 3                  Grapes  90.02
# 4                  Melons  85.48
# 5          Oranges, Total  89.35
# 6        Oranges as fruit  96.57
# 7            Orange juice  88.69
# 8      Other citrus fruit  77.85
# 9             Stone fruit   94.3
# 10         Tropical fruit  80.72

# %%
df_women4 = df_women4.drop(df_women4.index[6])
df_women4 = df_women4.reset_index(drop=True)

# %%
df_women4
# Out:
#                        f  07-08
# 0        Apples as fruit  91.69
# 1                Bananas   94.2
# 2                Berries  87.99
# 3                 Grapes  90.02
# 4                 Melons  85.48
# 5         Oranges, Total  89.35
# 6     Other citrus fruit  77.85
# 7            Stone fruit   94.3
# 8         Tropical fruit  80.72

# %%
df_women4=df_women4.drop('f',1)

# %%
df_women = df_women.join(df_women4)

# %%
df_women
# Out:
#              Fruit Types  94-98  03-04  05-06  07-08
# 0        Apples as fruit  90.42  91.21   91.5  91.69
# 1                Bananas  94.18  94.57  93.67   94.2
# 2                Berries  81.73  88.29  90.92  87.99
# 3                 Grapes  88.13  90.14  91.33  90.02
# 4                 Melons  84.96  80.99  93.57  85.48
# 5         Oranges, Total  89.77  88.07  88.86  89.35
# 6     Other citrus fruit  80.64   69.6  75.13  77.85
# 7            Stone fruit  89.55  87.94  89.61   94.3
# 8         Tropical fruit   80.4  85.85  76.57  80.72

# %%
df_women_t = df_women

# %%
df_dairy_men = df_dairy_men.transpose()

# %%
df_dairy_men = df_dairy_men[1:]

# %%
df_women_t
# Out:
#            0      1      2      3      4      5      6      7      8
# 94-98  90.42  94.18  81.73  88.13  84.96  89.77  80.64  89.55   80.4
# 03-04  91.21  94.57  88.29  90.14  80.99  88.07   69.6  87.94  85.85
# 05-06   91.5  93.67  90.92  91.33  93.57  88.86  75.13  89.61  76.57
# 07-08  91.69   94.2  87.99  90.02  85.48  89.35  77.85   94.3  80.72

# %%
df_women_t.columns=['Apples as fruit','Bananas','Berries','Grapes','Melons','Oranges,total','Other citrus fruit','Stone fruit','Tropical fruit']

# %%
df_women_t
# Out:
#       Apples as fruit Bananas Berries Grapes Melons Oranges,total  \
# 94-98           90.42   94.18   81.73  88.13  84.96         89.77
# 03-04           91.21   94.57   88.29  90.14  80.99         88.07
# 05-06            91.5   93.67   90.92  91.33  93.57         88.86
# 07-08           91.69    94.2   87.99  90.02  85.48         89.35
#
#       Other citrus fruit Stone fruit Tropical fruit
# 94-98              80.64       89.55           80.4
# 03-04               69.6       87.94          85.85
# 05-06              75.13       89.61          76.57
# 07-08              77.85        94.3          80.72

# %%
styles1 = ['-','--','--','-.','-','-.','--','-.','-']
df_women_t.plot(style=styles1)
plt.ylabel('Average % of at Home Fruit Consumption')
plt.xlabel('Year')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),ncol=3, fancybox=True, shadow=True)
plt.title('At Home Fruit Consumption for Women')
plt.text(0, 60, 'Commodity Availability by Food Source, 1994-2008 https://www.ers.usda.gov/publications/pub-details/?pubid=81817\nData: https://www.ers.usda.gov/webdocs/publications/err221/appendix%20b%20(shares).xls?v=42725')

# %% [markdown]
# In the figure above, we see that the average at home consumption of tropical fruit by women has fluctuated from 1994-2008. In 2008, it is near the same levels of consumption it wa sin 1994 after peaking and crashing in 2004 and 2006, repsectively. We see a similar trend for Melons across the same time period.

# %%
df_dairy_men = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='94-98 FAH')

# %%
df_dairy_men = df_dairy_men[107:116]

# %%
df_dairy_men
# Out:
#     Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 107                                  Fluid milk, Total
# 108                          Fluid milk, 1 percent fat
# 109                          Fluid milk, 2 percent fat
# 110                                   Fluid milk, Skim
# 111                                  Fluid Milk, Whole
# 112                                             Butter
# 113                                             Cheese
# 114                                             Yogurt
# 115                                       Dairy, Other
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 107      77.94      76.69      79.19      76.33      74.97      77.69
# 108      78.79      75.04      82.54       78.9      74.85      82.95
# 109      77.75      75.51      79.99      75.86      73.51      78.21
# 110      75.91       72.5      79.32       74.4      70.64      78.16
# ...

# %%
for i in range(1,16):
    if i != 7:
        df_dairy_men = df_dairy_men.drop('Unnamed: ' + str(i), 1)
        i+1

# %%
df_dairy_men
# Out:
#     Appendix Table B-1.  LAFA at-home shares: 1994-98 means and confidence intervals for U.S. children and adults  \
# 107                                  Fluid milk, Total
# 108                          Fluid milk, 1 percent fat
# 109                          Fluid milk, 2 percent fat
# 110                                   Fluid milk, Skim
# 111                                  Fluid Milk, Whole
# 112                                             Butter
# 113                                             Cheese
# 114                                             Yogurt
# 115                                       Dairy, Other
#
#     Unnamed: 7
# 107      82.57
# 108      90.85
# 109      89.02
# 110       76.3
# 111      79.41
# 112      65.97
# 113      57.47
# 114      89.68
# 115      66.56

# %%
df_dairy_men.columns=['Dairy Types','94-98']

# %%
df_dairy_men
# Out:
#                         Dairy Types  94-98
# 107               Fluid milk, Total  82.57
# 108       Fluid milk, 1 percent fat  90.85
# 109       Fluid milk, 2 percent fat  89.02
# 110                Fluid milk, Skim   76.3
# 111               Fluid Milk, Whole  79.41
# 112                          Butter  65.97
# 113                          Cheese  57.47
# 114                          Yogurt  89.68
# 115                    Dairy, Other  66.56

# %%
#df_men2 = df_men2.drop(df_men.index[0])
df_dairy_men = df_dairy_men.reset_index(drop=True)

# %%
df_dairy_men
# Out:
#                       Dairy Types  94-98
# 0               Fluid milk, Total  82.57
# 1       Fluid milk, 1 percent fat  90.85
# 2       Fluid milk, 2 percent fat  89.02
# 3                Fluid milk, Skim   76.3
# 4               Fluid Milk, Whole  79.41
# 5                          Butter  65.97
# 6                          Cheese  57.47
# 7                          Yogurt  89.68
# 8                    Dairy, Other  66.56

# %%
df_dairy_men = df_dairy_men.drop(df_dairy_men.index[1:5])
df_dairy_men = df_dairy_men.reset_index(drop=True)

# %%
df_dairy_men
# Out:
#             Dairy Types  94-98
# 0     Fluid milk, Total  82.57
# 1                Butter  65.97
# 2                Cheese  57.47
# 3                Yogurt  89.68
# 4          Dairy, Other  66.56

# %%
df_dairy_men2 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='03-04 FAH')

# %%
df_dairy_men2 = df_dairy_men2[107:116]

# %%
for i in range(1,16):
    if i != 7:
        df_dairy_men2 = df_dairy_men2.drop('Unnamed: ' + str(i), 1)
        i+1

# %%
df_dairy_men2.columns=['dairy','03-04']

# %%
df_dairy_men2
# Out:
#                               dairy  03-04
# 107               Fluid milk, Total  88.83
# 108       Fluid milk, 1 percent fat  91.85
# 109       Fluid milk, 2 percent fat  90.82
# 110                Fluid milk, Skim  87.47
# 111               Fluid Milk, Whole  86.84
# 112                          Butter     74
# 113                          Cheese   56.3
# 114                          Yogurt  87.12
# 115                    Dairy, Other  73.48

# %%
df_dairy_men2 = df_dairy_men2.reset_index(drop=True)
df_dairy_men2 = df_dairy_men2.drop(df_dairy_men.index[1:5])

# %%
df_dairy_men2
# Out:
#                   dairy  03-04
# 0     Fluid milk, Total  88.83
# 5                Butter     74
# 6                Cheese   56.3
# 7                Yogurt  87.12
# 8          Dairy, Other  73.48

# %%
df_dairy_men2 = df_dairy_men2.reset_index(drop=True)

# %%
df_dairy_men2
# Out:
#                   dairy  03-04
# 0     Fluid milk, Total  88.83
# 1                Butter     74
# 2                Cheese   56.3
# 3                Yogurt  87.12
# 4          Dairy, Other  73.48

# %%
df_dairy_men = df_dairy_men.join(df_dairy_men2)

# %%
df_dairy_men2.drop('dairy',1)
# Out:
#    03-04
# 0  88.83
# 1     74
# 2   56.3
# 3  87.12
# 4  73.48

# %%
df_dairy_men
# Out:
#             Dairy Types  94-98                 dairy  03-04
# 0     Fluid milk, Total  82.57     Fluid milk, Total  88.83
# 1                Butter  65.97                Butter     74
# 2                Cheese  57.47                Cheese   56.3
# 3                Yogurt  89.68                Yogurt  87.12
# 4          Dairy, Other  66.56          Dairy, Other  73.48

# %%
df_dairy_men = df_dairy_men.drop('dairy',1)

# %%
df_dairy_men
# Out:
#             Dairy Types  94-98  03-04
# 0     Fluid milk, Total  82.57  88.83
# 1                Butter  65.97     74
# 2                Cheese  57.47   56.3
# 3                Yogurt  89.68  87.12
# 4          Dairy, Other  66.56  73.48

# %%
df_dairy_men3 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='05-06 FAH')

# %%
df_dairy_men3 = df_dairy_men3[107:116]

# %%
for i in range(1,16):
    if i != 7:
        df_dairy_men3 = df_dairy_men3.drop('Unnamed: ' + str(i), 1)
        i+1

# %%
df_dairy_men3.columns=['dairy','05-06']

# %%
df_dairy_men3
# Out:
#                               dairy  05-06
# 107               Fluid milk, Total  88.61
# 108       Fluid milk, 1 percent fat   91.1
# 109       Fluid milk, 2 percent fat  92.91
# 110                Fluid milk, Skim  86.32
# 111               Fluid Milk, Whole  84.34
# 112                          Butter  77.54
# 113                          Cheese  54.56
# 114                          Yogurt  94.38
# 115                    Dairy, Other  69.41

# %%
df_dairy_men3 = df_dairy_men3.reset_index(drop=True)
df_dairy_men3 = df_dairy_men3.drop(df_dairy_men3.index[1:5])

# %%
df_dairy_men3
# Out:
#                   dairy  05-06
# 0     Fluid milk, Total  88.61
# 1                Butter  77.54
# 2                Cheese  54.56
# 3                Yogurt  94.38
# 4          Dairy, Other  69.41

# %%
df_dairy_men3 = df_dairy_men3.reset_index(drop=True)

# %%
df_dairy_men3 = df_dairy_men3.drop('dairy',1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-291-6f1fe23afeb4> in <module>()
# ----> 1 df_dairy_men3 = df_dairy_men3.drop('dairy',1)
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/mhendrickson/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
# ...

# %%
df_dairy_men = df_dairy_men.join(df_dairy_men3)

# %%
df_dairy_men
# Out:
#             Dairy Types  94-98  03-04  05-06
# 0     Fluid milk, Total  82.57  88.83  88.61
# 1                Butter  65.97     74  77.54
# 2                Cheese  57.47   56.3  54.56
# 3                Yogurt  89.68  87.12  94.38
# 4          Dairy, Other  66.56  73.48  69.41

# %%
df_dairy_men4 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='05-06 FAH')
df_dairy_men4 = df_dairy_men4[107:116]
for i in range(1,16):
    if i != 7:
        df_dairy_men4 = df_dairy_men4.drop('Unnamed: ' + str(i), 1)
        i+1
df_dairy_men4.columns=['dairy','05-06']
df_dairy_men4 = df_dairy_men4.reset_index(drop=True)
df_dairy_men4 = df_dairy_men4.drop(df_dairy_men4.index[1:5])
df_dairy_men4 = df_dairy_men4.reset_index(drop=True)

# %%
df_dairy_men4 = df_dairy_men4.drop('dairy',1)

# %%
df_dairy_men4.columns=['07-08']

# %%
df_dairy_men = df_dairy_men.join(df_dairy_men4)

# %%
df_dairy_men
# Out:
#            0      1      2      3      4
# 94-98  82.57  65.97  57.47  89.68  66.56
# 03-04  88.83     74   56.3  87.12  73.48
# 05-06  88.61  77.54  54.56  94.38  69.41
# 07-08  88.61  77.54  54.56  94.38  69.41

# %%
df_dairy_men.columns=['Fluid Milk','Butter','Cheese','Yogurt','Dairy,other']
styles1 = ['-','--','--','-.','-','-.','--','-.','-']
df_dairy_men.plot(style=styles1)
plt.ylabel('Average % of at Home Dairy Consumption')
plt.xlabel('Year')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),ncol=3, fancybox=True, shadow=True)
plt.title('At Home Dairy Consumption for Men')
plt.text(0, 40, 'Commodity Availability by Food Source, 1994-2008 https://www.ers.usda.gov/publications/pub-details/?pubid=81817\nData: https://www.ers.usda.gov/webdocs/publications/err221/appendix%20b%20(shares).xls?v=42725')

# %% [markdown]
# We see the largest growth of at home dairy consumption from 1994-2009 is butter. This may be due to health studies that differentiated between the pros and cons of butter versus immitation butters like margarine. Over the same time period, we see an increase of at home yogurt consumption increase 5%.

# %%
df_dairy_women2 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='03-04 FAH')
df_dairy_women2 = df_dairy_women2[107:116]
for i in range(1,16):
    if i != 10:
        df_dairy_women2 = df_dairy_women2.drop('Unnamed: ' + str(i), 1)
        i+1
df_dairy_women2.columns=['dairy','03-04']
df_dairy_women2 = df_dairy_women2.reset_index(drop=True)
df_dairy_women2 = df_dairy_women2.drop(df_dairy_women2.index[1:5])
df_dairy_women2 = df_dairy_women2.reset_index(drop=True)

# %%
df_dairy_women
# Out:
#                   dairy  94-98
# 0     Fluid milk, Total  86.69
# 1                Butter  70.66
# 2                Cheese  62.24
# 3                Yogurt  88.22
# 4          Dairy, Other  65.48

# %%
df_dairy_women2 = df_dairy_women2.drop('dairy',1)

# %%
df_dairy_women=df_dairy_women.join(df_dairy_women2)

# %%
df_dairy_women
# Out:
#                   dairy  94-98  03-04
# 0     Fluid milk, Total  86.69  88.92
# 1                Butter  70.66  72.57
# 2                Cheese  62.24  59.72
# 3                Yogurt  88.22  90.57
# 4          Dairy, Other  65.48  69.77

# %%
df_dairy_women3 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='05-06 FAH')
df_dairy_women3 = df_dairy_women3[107:116]
for i in range(1,16):
    if i != 10:
        df_dairy_women3 = df_dairy_women3.drop('Unnamed: ' + str(i), 1)
        i+1
df_dairy_women3.columns=['dairy','05-06']
df_dairy_women3 = df_dairy_women3.reset_index(drop=True)
df_dairy_women3 = df_dairy_women3.drop(df_dairy_women3.index[1:5])
df_dairy_women3 = df_dairy_women3.reset_index(drop=True)
df_dairy_women3 = df_dairy_women3.drop('dairy',1)
df_dairy_women=df_dairy_women.join(df_dairy_women3)

# %%
df_dairy_women
# Out:
#                   dairy  94-98  03-04  05-06
# 0     Fluid milk, Total  86.69  88.92  89.69
# 1                Butter  70.66  72.57  79.72
# 2                Cheese  62.24  59.72  63.35
# 3                Yogurt  88.22  90.57  94.82
# 4          Dairy, Other  65.48  69.77  65.94

# %%
df_dairy_women4 = pd.read_excel(open('USFoodCommodity.xls','rb'), sheetname='07-08 FAH')
df_dairy_women4 = df_dairy_women4[107:116]
for i in range(1,16):
    if i != 10:
        df_dairy_women4 = df_dairy_women4.drop('Unnamed: ' + str(i), 1)
        i+1
df_dairy_women4.columns=['dairy','07-08']
df_dairy_women4 = df_dairy_women4.reset_index(drop=True)
df_dairy_women4 = df_dairy_women4.drop(df_dairy_women4.index[1:5])
df_dairy_women4 = df_dairy_women4.reset_index(drop=True)
df_dairy_women4 = df_dairy_women4.drop('dairy',1)
df_dairy_women=df_dairy_women.join(df_dairy_women4)

# %%
df_dairy_women
# Out:
#                   dairy  94-98  03-04  05-06  07-08
# 0     Fluid milk, Total  86.69  88.92  89.69  88.38
# 1                Butter  70.66  72.57  79.72  76.82
# 2                Cheese  62.24  59.72  63.35  62.24
# 3                Yogurt  88.22  90.57  94.82  92.56
# 4          Dairy, Other  65.48  69.77  65.94  72.39

# %%
df_dairy_women = df_dairy_women.transpose()

# %%
df_dairy_women
# Out:
#                           0          1          2          3                4
# dairy     Fluid milk, Total     Butter     Cheese     Yogurt     Dairy, Other
# 94-98                 86.69      70.66      62.24      88.22            65.48
# 03-04                 88.92      72.57      59.72      90.57            69.77
# 05-06                 89.69      79.72      63.35      94.82            65.94
# 07-08                 88.38      76.82      62.24      92.56            72.39

# %%
df_dairy_women = df_dairy_women.drop(df_dairy_women.index[0])

# %%
df_dairy_women
# Out:
#            0      1      2      3      4
# 94-98  86.69  70.66  62.24  88.22  65.48
# 03-04  88.92  72.57  59.72  90.57  69.77
# 05-06  89.69  79.72  63.35  94.82  65.94
# 07-08  88.38  76.82  62.24  92.56  72.39

# %%
df_dairy_women.columns=['Fluid Milk','Butter','Cheese','Yogurt','Dairy,other']
styles1 = ['-','--','--','-.','-','-.','--','-.','-']
df_dairy_women.plot(style=styles1)
plt.ylabel('Average % of at Home Dairy Consumption')
plt.xlabel('Year')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),ncol=3, fancybox=True, shadow=True)
plt.title('At Home Dairy Consumption for Women')
plt.text(0, 45, 'Commodity Availability by Food Source, 1994-2008 https://www.ers.usda.gov/publications/pub-details/?pubid=81817\nData: https://www.ers.usda.gov/webdocs/publications/err221/appendix%20b%20(shares).xls?v=42725')

# %% [markdown]
# From 1994-2008 butter saw the same uptick in at home consumption for women as it did for men. We see that the at home consumption of cheese srated relatively the same.
